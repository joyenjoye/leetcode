# %% [markdown]
# https://leetcode-cn.com/problems/linked-list-cycle/

# %%
from typing import Optional
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %% [markdown]
# ## Solution 1
#
# |  Python3  |         |  |
# |:--------:|:-------:|---------------|
# | 运行时长(ms) | 52| 76.84%        |
# |   内存消耗(mb)      | 18.5 | 44.29%

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def sortList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        
        curr = head
        dummy = ListNode()
        iter_ = dummy
        while curr.next:
            print("------")
            print(curr.val)
            next_ = curr.next
            if  next_.val<curr.val:
                if next_.val<iter_.val:
                    print(next_.val)
                    next_.next = iter_
                    iter_ = next_
                else:
                    next_.next = curr
                    iter_.next = next_

                return dummy.next
                # iter_ = iter_.next
                    
                # else:
                #     curr.next = None
                #     next_.next = curr
                #     iter_.next = next_
                #     break
            else:
                curr.next.next = None
                iter_.next = curr
                curr = next_
        
            
        return dummy.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def sortList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        
        curr = head
        dummy = ListNode()
        iter_ = dummy
        while curr.next:
            print("------")
            print(curr.val)
            next_ = curr.next
            if  next_.val<curr.val:
                if next_.val<iter_.val:
                    print(next_.val)
                    next_.next = iter_
                    iter_ = next_
                else:
                    next_.next = curr
                    iter_.next = next_

                return dummy.next
                # iter_ = iter_.next
                    
                # else:
                #     curr.next = None
                #     next_.next = curr
                #     iter_.next = next_
                #     break
            else:
                curr.next.next = None
                iter_.next = curr
                curr = next_
        
            
        return dummy.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:

    def print_(self,head):
        iter_ = head
        res = []
        while iter_:
            res.append(iter_.val)
            iter_ = iter_.next
        print(res)
        

    def sortList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head:
            return head
        curr = head.next
        prev = ListNode(val = 0)
        prev.next = ListNode(val = head.val)
        iter_ = prev

        while curr:
            print("------")
            print(curr.val,iter_.next.val)

            temp = ListNode(val=curr.val)

            if curr.val<iter_.next.val:
                temp.next = iter_.next
                iter_.next= temp    

            else:
                iter__ = prev.next
                if iter__.next:
                    while iter__.next:
                        if iter__.val<curr.val and  curr.val<iter__.next.val:
                            temp.next =iter__.next
                            iter__.next = temp
                        else:
                            iter__ = iter__.next
                else:
                    iter_.next.next = temp  
              
               
                   
            curr = curr.next
            

            self.print_(prev.next)
            
        return prev.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:

    def sortList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head:
            return head
        curr = head.next
        prev = ListNode(val = 0)
        prev.next = ListNode(val = head.val)
        iter_ = prev

        while curr:

            temp = ListNode(val=curr.val)

            if curr.val<iter_.next.val:
                temp.next = iter_.next
                iter_.next= temp    

            else:
                iter__ = prev.next
                if iter__.next:
                    while iter__:
                        if iter__.val<=curr.val:
                            if iter__.next is None:
                                temp.next =iter__.next
                                iter__.next = temp
                                break
                                
                            elif curr.val<=iter__.next.val:
                                temp.next =iter__.next
                                iter__.next = temp
                                break
                           
                        iter__ = iter__.next

                else:
                    iter_.next.next = temp  
              
               
                   
            curr = curr.next
            
        return prev.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def print_(self,head):
        iter_ = head
        res = []
        while iter_:
            res.append(iter_.val)
            iter_ = iter_.next
        print(res)

    def sortList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head:
            return head
 
        head = ListNode(val = 0, next = head)
        itr = head
        itr_ = head
        k = 0
        while itr.next.next:
            print("----")
            self.print_(itr)
            curr = itr.next
            next_ = itr.next.next
            if k>0 and next_.val<itr_.next.val:
                itr_.next = ListNode(val=next_.val,next=itr_.next)
                itr.next.next = next_.next
            elif curr.val>next_.val:
                itr.next = next_
                itr.next.next =ListNode(curr.val,next=next_.next)
            else:
                itr = itr.next
            k=k+1
        
        return head.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def print_(self,head):
        iter_ = head
        res = []
        while iter_:
            res.append(iter_.val)
            iter_ = iter_.next
        print(res)

    def sortList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head:
            return head
 
        head = ListNode(val = 0, next = head)
        itr = head
        itr_ = head
        k = 0
        while itr.next.next:
            print("----")
            self.print_(itr)
            curr = itr.next
            next_ = itr.next.next
            if k>0 and next_.val<itr_.next.val:
                itr_.next = ListNode(val=next_.val,next=itr_.next)
                itr.next.next = next_.next
            elif curr.val>next_.val:
                itr.next = next_
                itr.next.next =ListNode(curr.val,next=next_.next)
            else:
                itr = itr.next
            k=k+1
        

        return head.next
